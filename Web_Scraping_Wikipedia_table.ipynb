# %% [markdown]
# <a href="https://colab.research.google.com/github/mjgalaz/Supermarket-ETL-Web-scraping/blob/main/Web_Scraping_Wikipedia_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Web scraping wikipedia con BeautifulSoup

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL de la página web
url = 'https://en.wikipedia.org/wiki/List_of_supermarket_chains'

# Obtener el HTML de la página
response = requests.get(url)
html_content = response.content

# Utilizar BeautifulSoup para procesar el HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Encontrar la tabla de interés
table = soup.find('table', {'class': 'wikitable'})

# Reemplazar etiquetas <br> por comas en la columna 'Headquarters' antes de leer la tabla con Pandas
for br in table.find_all('br'):
    br.replace_with(', ')

# Leer la tabla en un DataFrame de Pandas
tabla_multinational = pd.read_html(str(table))[0]

# Eliminar la columna 'Map'
tabla_multinational.drop(columns=['Map'], inplace=True)

# Mostrar el DataFrame
display(tabla_multinational)
# Out:
#                    Company          Headquarters  \
# 0                 7-Eleven  Japan, United States
# 1                     Aeon                 Japan
# 2           Ahold Delhaize           Netherlands
# 3                Aldi Nord               Germany
# 4                 Aldi Süd               Germany
# ..                     ...                   ...
# 360  Robinsons Supermarket           Philippines
# 361              SM Retail           Philippines
# 362              citysuper             Hong Kong
# 363           Kansai Super                 Japan
# 364            Extra Foods                Canada
#
#            Served countries (besides the headquarters) Number of locations  \
# 0    Australia, Canada, China, Cambodia, Denmark, H...               83485
# 1    Australia, Cambodia, China, Hong Kong, India, ...               20008
# 2    Belgium (as Albert Heijn and Delhaize), Czech ...                7659
# 3    Belgium, Denmark, France, Luxembourg, Netherla...                5241
# 4    Australia, Austria (as Hofer), China, Hungary,...                7178
# ..                                                 ...                 ...
# 360                                                NaN                 274
# 361                                                NaN                 NaN
# 362                             Taiwan, Mainland China                  41
# 363                                                NaN                  60
# 364                                                NaN                   4
#
#     Number of employees
# 0                170000
# 1              560,000+
# 2                375000
# 3                 72811
# 4                201361
# ..                  ...
# 360                 NaN
# 361                 NaN
# 362                 NaN
# 363                 NaN
# 364                 NaN
#
# [365 rows x 5 columns]

# %% [markdown]
# Copia tabla obtenida

# %%
# Crear una copia del DataFrame
copia_tabla_multinational = tabla_multinational.copy()

# Mostrar la copia del DataFrame
display(copia_tabla_multinational)
# Out:
#                    Company          Headquarters  \
# 0                 7-Eleven  Japan, United States
# 1                     Aeon                 Japan
# 2           Ahold Delhaize           Netherlands
# 3                Aldi Nord               Germany
# 4                 Aldi Süd               Germany
# ..                     ...                   ...
# 360  Robinsons Supermarket           Philippines
# 361              SM Retail           Philippines
# 362              citysuper             Hong Kong
# 363           Kansai Super                 Japan
# 364            Extra Foods                Canada
#
#            Served countries (besides the headquarters) Number of locations  \
# 0    Australia, Canada, China, Cambodia, Denmark, H...               83485
# 1    Australia, Cambodia, China, Hong Kong, India, ...               20008
# 2    Belgium (as Albert Heijn and Delhaize), Czech ...                7659
# 3    Belgium, Denmark, France, Luxembourg, Netherla...                5241
# 4    Australia, Austria (as Hofer), China, Hungary,...                7178
# ..                                                 ...                 ...
# 360                                                NaN                 274
# 361                                                NaN                 NaN
# 362                             Taiwan, Mainland China                  41
# 363                                                NaN                  60
# 364                                                NaN                   4
#
#     Number of employees
# 0                170000
# 1              560,000+
# 2                375000
# 3                 72811
# 4                201361
# ..                  ...
# 360                 NaN
# 361                 NaN
# 362                 NaN
# 363                 NaN
# 364                 NaN
#
# [365 rows x 5 columns]

# %% [markdown]
# Limpiar tabla obtenida

# %%
# Agrupar variables numéricas
numeric_cols = ['Number of locations', 'Number of employees']

# Eliminar texto entre paréntesis en la columna 'Served countries (besides the headquarters)'
copia_tabla_multinational['Served countries (besides the headquarters)'] = copia_tabla_multinational['Served countries (besides the headquarters)'].str.replace(r'\(.*?\)', '', regex=True)

# Eliminar texto entre paréntesis en la columna 'Headquarters'
copia_tabla_multinational['Headquarters'] = copia_tabla_multinational['Headquarters'].str.replace(r'\(.*?\)', '', regex=True)

# Reemplazar 'USA' por 'United States' en la columna 'Served countries (besides the headquarters)'
copia_tabla_multinational['Served countries (besides the headquarters)'] = copia_tabla_multinational['Served countries (besides the headquarters)'].str.replace('USA', 'United States')
# Reemplazar un valor específico por otro en la columna 'Served countries (besides the headquarters)'
copia_tabla_multinational['Served countries (besides the headquarters)'] = copia_tabla_multinational['Served countries (besides the headquarters)'].replace('Colombia branded as ARA, Poland branded as Biedronka', 'Colombia, Poland')

import re
# Definir patrón de búsqueda para encontrar 'and' que no esté seguido por 'Bosnia and Herzegovina'
patron = r'\b(?!Bosnia\s+and\s+Herzegovina\b)(and)\b'

# Aplicar reemplazo en la columna 'Served countries (besides the headquarters)'
copia_tabla_multinational['Served countries (besides the headquarters)'] = copia_tabla_multinational['Served countries (besides the headquarters)'].str.replace(patron, ',', regex=True)

# Limpiar la variable 'Company'
copia_tabla_multinational['Company'] = copia_tabla_multinational['Company'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)
copia_tabla_multinational['Company'] = copia_tabla_multinational['Company'].str.lower()

# Limpiar la variable 'Headquarters'
copia_tabla_multinational['Headquarters'] = copia_tabla_multinational['Headquarters'].str.lower()

# Limpiar los datos de caracteres especiales salvo las comas de la variable 'Served countries (besides the headquarters)'
copia_tabla_multinational['Served countries (besides the headquarters)'] = copia_tabla_multinational['Served countries (besides the headquarters)'].str.replace(r'[^\w\s,]', '', regex=True)
#Poner en minuscula los datos de la variable Served countries (besides the headquarters)'
copia_tabla_multinational['Served countries (besides the headquarters)'] = copia_tabla_multinational['Served countries (besides the headquarters)'].str.lower()

# Eliminar el signo "+" y la coma de las columnas en numeric_cols
for col in numeric_cols:
    copia_tabla_multinational[col] = copia_tabla_multinational[col].str.replace('[\+,]', '', regex=True)

# Eliminar todo después del primer número en las columnas en numeric_cols
for col in numeric_cols:
    copia_tabla_multinational[col] = copia_tabla_multinational[col].str.replace(r'^(\d+).*', r'\1', regex=True)

from unicodedata import normalize
# Función para normalizar datos con Unicode para luego quitar los espacios usando .replace().
# Argumentos de entrada: Nombre de columna o lista con nombres de columnas.
# Retorna: columna o columnas sin espacios en blanco
def remove_whitespace(x):

    if isinstance(x, str):
        return normalize('NFKC', x).replace(' ', '')
    else:
        return x

# Aplicar función remove_whitespace a columnas en variable y las reemplazamos en la copia
copia_tabla_multinational[numeric_cols] = copia_tabla_multinational[numeric_cols].applymap(remove_whitespace)

# Verificamos si se quitaron los espacios en blanco
copia_tabla_multinational.head()

# Mostrar tipo de datos de la copia
copia_tabla_multinational.dtypes

# Asignar el tipo de dato numérico a columnas en la copia
copia_tabla_multinational[numeric_cols] = copia_tabla_multinational[numeric_cols].apply(pd.to_numeric)

# Convertir las columnas 'Company', 'Headquarters' y 'Served countries (besides the headquarters)' al tipo de dato string
copia_tabla_multinational['Company'] = copia_tabla_multinational['Company'].astype('string')
copia_tabla_multinational['Headquarters'] = copia_tabla_multinational['Headquarters'].astype('string')
copia_tabla_multinational['Served countries (besides the headquarters)'] = copia_tabla_multinational['Served countries (besides the headquarters)'].astype('string')

# Ver tabla
display(copia_tabla_multinational)

# Verificamos que las columnas con números tengan el tipo de dato numérico asignado en la copia
copia_tabla_multinational.dtypes
# Out:
#                    Company          Headquarters  \
# 0                  7eleven  japan, united states
# 1                     aeon                 japan
# 2           ahold delhaize           netherlands
# 3                aldi nord               germany
# 4                  aldi sd               germany
# ..                     ...                   ...
# 360  robinsons supermarket           philippines
# 361              sm retail           philippines
# 362              citysuper             hong kong
# 363           kansai super                 japan
# 364            extra foods                canada
#
#            Served countries (besides the headquarters)  Number of locations  \
# 0    australia, canada, china, cambodia, denmark, h...              83485.0
# 1    australia, cambodia, china, hong kong, india, ...              20008.0
# 2    belgium , czech republic , greece , indonesia ...               7659.0
# 3    belgium, denmark, france, luxembourg, netherla...               5241.0
# 4    australia, austria , china, hungary, ireland, ...               7178.0
# ..                                                 ...                  ...
# 360                                               <NA>                274.0
# 361                                               <NA>                  NaN
# 362                             taiwan, mainland china                 41.0
# 363                                               <NA>                 60.0
# 364                                               <NA>                  4.0
#
#      Number of employees
# 0               170000.0
# 1               560000.0
# 2               375000.0
# 3                72811.0
# 4               201361.0
# ..                   ...
# 360                  NaN
# 361                  NaN
# 362                  NaN
# 363                  NaN
# 364                  NaN
#
# [365 rows x 5 columns]
# Company                                         string
# Headquarters                                    string
# Served countries (besides the headquarters)     string
# Number of locations                            float64
# Number of employees                            float64
# dtype: object

# %% [markdown]
# Nueva variable countries

# %%
import pandas as pd

# Suponiendo que tienes un DataFrame llamado copia_tabla_multinational con las columnas 'Headquarters' y 'Served countries (besides the headquarters)'

# Llenar los valores NA con una cadena vacía en las columnas 'Headquarters' y 'Served countries (besides the headquarters)'
copia_tabla_multinational['Headquarters'].fillna('', inplace=True)
copia_tabla_multinational['Served countries (besides the headquarters)'].fillna('', inplace=True)

# Concatenar las columnas 'Headquarters' y 'Served countries (besides the headquarters)'
copia_tabla_multinational['countries'] = copia_tabla_multinational['Headquarters'].str.cat(copia_tabla_multinational['Served countries (besides the headquarters)'], sep=', ')

# Eliminar la coma inicial y final si está presente
copia_tabla_multinational['countries'] = copia_tabla_multinational['countries'].apply(lambda x: x.strip(', '))

# Mostrar el DataFrame con la nueva columna 'countries'
display(copia_tabla_multinational)
# Out:
#                    Company          Headquarters  \
# 0                  7eleven  japan, united states
# 1                     aeon                 japan
# 2           ahold delhaize           netherlands
# 3                aldi nord               germany
# 4                  aldi sd               germany
# ..                     ...                   ...
# 360  robinsons supermarket           philippines
# 361              sm retail           philippines
# 362              citysuper             hong kong
# 363           kansai super                 japan
# 364            extra foods                canada
#
#            Served countries (besides the headquarters)  Number of locations  \
# 0    australia, canada, china, cambodia, denmark, h...              83485.0
# 1    australia, cambodia, china, hong kong, india, ...              20008.0
# 2    belgium , czech republic , greece , indonesia ...               7659.0
# 3    belgium, denmark, france, luxembourg, netherla...               5241.0
# 4    australia, austria , china, hungary, ireland, ...               7178.0
# ..                                                 ...                  ...
# 360                                                                   274.0
# 361                                                                     NaN
# 362                             taiwan, mainland china                 41.0
# 363                                                                    60.0
# 364                                                                     4.0
#
#      Number of employees                                          countries
# 0               170000.0  japan, united states, australia, canada, china...
# 1               560000.0  japan, australia, cambodia, china, hong kong, ...
# 2               375000.0  netherlands, belgium , czech republic , greece...
# 3                72811.0  germany, belgium, denmark, france, luxembourg,...
# 4               201361.0  germany, australia, austria , china, hungary, ...
# ..                   ...                                                ...
# 360                  NaN                                        philippines
# 361                  NaN                                        philippines
# 362                  NaN                  hong kong, taiwan, mainland china
# 363                  NaN                                              japan
# 364                  NaN                                             canada
#
# [365 rows x 6 columns]

# %% [markdown]
# Tabla limpia

# %%
# Seleccionar las columnas deseadas
tabla_multinational_limpia = copia_tabla_multinational[['Company','countries','Number of locations', 'Number of employees']].copy()

# Mostrar el DataFrame limpia
display(tabla_multinational_limpia)
# Out:
#                    Company                                          countries  \
# 0                  7eleven  japan, united states, australia, canada, china...
# 1                     aeon  japan, australia, cambodia, china, hong kong, ...
# 2           ahold delhaize  netherlands, belgium , czech republic , greece...
# 3                aldi nord  germany, belgium, denmark, france, luxembourg,...
# 4                  aldi sd  germany, australia, austria , china, hungary, ...
# ..                     ...                                                ...
# 360  robinsons supermarket                                        philippines
# 361              sm retail                                        philippines
# 362              citysuper                  hong kong, taiwan, mainland china
# 363           kansai super                                              japan
# 364            extra foods                                             canada
#
#      Number of locations  Number of employees
# 0                83485.0             170000.0
# 1                20008.0             560000.0
# 2                 7659.0             375000.0
# 3                 5241.0              72811.0
# 4                 7178.0             201361.0
# ..                   ...                  ...
# 360                274.0                  NaN
# 361                  NaN                  NaN
# 362                 41.0                  NaN
# 363                 60.0                  NaN
# 364                  4.0                  NaN
#
# [365 rows x 4 columns]

# %% [markdown]
# Limpia nueva variable countries

# %%
# Eliminar espacios en blanco antes y después de las comas
tabla_multinational_limpia['countries'] = tabla_multinational_limpia['countries'].str.replace(r'[^\w\s,]', '', regex=True)
tabla_multinational_limpia['countries'] = tabla_multinational_limpia['countries'].apply(lambda x: ','.join([country.strip() for country in x.split(',')]))
display(tabla_multinational_limpia)
# Out:
#                    Company                                          countries  \
# 0                  7eleven  japan,united states,australia,canada,china,cam...
# 1                     aeon  japan,australia,cambodia,china,hong kong,india...
# 2           ahold delhaize  netherlands,belgium,czech republic,greece,indo...
# 3                aldi nord  germany,belgium,denmark,france,luxembourg,neth...
# 4                  aldi sd  germany,australia,austria,china,hungary,irelan...
# ..                     ...                                                ...
# 360  robinsons supermarket                                        philippines
# 361              sm retail                                        philippines
# 362              citysuper                    hong kong,taiwan,mainland china
# 363           kansai super                                              japan
# 364            extra foods                                             canada
#
#      Number of locations  Number of employees
# 0                83485.0             170000.0
# 1                20008.0             560000.0
# 2                 7659.0             375000.0
# 3                 5241.0              72811.0
# 4                 7178.0             201361.0
# ..                   ...                  ...
# 360                274.0                  NaN
# 361                  NaN                  NaN
# 362                 41.0                  NaN
# 363                 60.0                  NaN
# 364                  4.0                  NaN
#
# [365 rows x 4 columns]

# %% [markdown]
# Reordenar tabla por país

# %%
import pandas as pd

# Supongamos que tienes un DataFrame llamado tabla_multinational_limpia

# Creamos una lista para almacenar las filas duplicadas
rows = []

# Iteramos sobre cada fila del DataFrame original
for index, row in tabla_multinational_limpia.iterrows():
    # Dividimos la lista de países
    countries = row['countries'].split(',')
    # Iteramos sobre cada país en la lista
    for country in countries:
        # Creamos una copia de la fila actual
        new_row = row.copy()
        # Asignamos el país actual a la nueva fila
        new_row['country'] = country.strip()  # Eliminamos los espacios en blanco alrededor del país
        # Añadimos la fila duplicada a la lista
        rows.append(new_row)

# Creamos un nuevo DataFrame con las filas duplicadas
tabla_multinational_final = pd.DataFrame(rows)

# Eliminamos la columna 'countries'
tabla_multinational_final.drop(columns=['countries'], inplace=True)

# Reordenamos las columnas colocando 'country' en primer lugar
tabla_multinational_final = tabla_multinational_final[['country', 'Company', 'Number of locations', 'Number of employees']]

# Ordenar el DataFrame por la columna 'country'
tabla_multinational_final = tabla_multinational_final.sort_values(by='country')

# Eliminar filas donde 'country' sea una cadena vacía
tabla_multinational_final = tabla_multinational_final[tabla_multinational_final['country'] != '']

# Mostramos el DataFrame resultante
display(tabla_multinational_final)
# Out:
#       country                Company  Number of locations  Number of employees
# 20    albania                  conad               3410.0              32000.0
# 34    albania                   crai               3444.0              18000.0
# 83    albania                   spar              13623.0             410000.0
# 14    algeria              carrefour              13894.0             319565.0
# 303   andorra                caprabo                  NaN                  NaN
# ..        ...                    ...                  ...                  ...
# 57      yemen       lulu hypermarket                238.0              57000.0
# 235    zambia  shoprite holdings ltd               3326.0             153000.0
# 83     zambia                   spar              13623.0             410000.0
# 235  zimbabwe  shoprite holdings ltd               3326.0             153000.0
# 83   zimbabwe                   spar              13623.0             410000.0
#
# [1107 rows x 4 columns]

# %% [markdown]
# Guardar tabla final en formato csv

# %%
# Guarda el DataFrame en un archivo CSV
tabla_multinational_final.to_csv('tabla_multinational_final.csv',index=False)

# Lee el archivo para verificar su creación
pd.read_csv('tabla_multinational_final.csv')
# Out:
#        country                Company  Number of locations  \
# 0      albania                  conad               3410.0
# 1      albania                   crai               3444.0
# 2      albania                   spar              13623.0
# 3      algeria              carrefour              13894.0
# 4      andorra                caprabo                  NaN
# ...        ...                    ...                  ...
# 1102     yemen       lulu hypermarket                238.0
# 1103    zambia  shoprite holdings ltd               3326.0
# 1104    zambia                   spar              13623.0
# 1105  zimbabwe  shoprite holdings ltd               3326.0
# 1106  zimbabwe                   spar              13623.0
#
#       Number of employees
# 0                 32000.0
# 1                 18000.0
# 2                410000.0
# 3                319565.0
# 4                     NaN
# ...                   ...
# 1102              57000.0
# 1103             153000.0
# 1104             410000.0
# 1105             153000.0
# 1106             410000.0
#
# [1107 rows x 4 columns]

# %% [markdown]
# Guardar tabla final en formato csv en el ordenador

# %%
# Cargar o descargar archivos
from google.colab import files

# Descarga archivo con datos de tabla
files.download("tabla_multinational_final.csv")

print('Listo, en un momento saldrá la opción "Guardar Como" para descargar el archivo...')
# Out:
# Listo, en un momento saldrá la opción "Guardar Como" para descargar el archivo...
